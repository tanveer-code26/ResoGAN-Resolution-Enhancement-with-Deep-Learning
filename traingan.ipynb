# %%
import os
import numpy as np
from tensorflow.keras.layers import (Input, Conv2D, LeakyReLU, BatchNormalization, 
                                     Add, Flatten, Dense, UpSampling2D, Activation)
from tensorflow.keras.models import Model 
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Paths to datasets
TRAINING_DATASET_PATH = "F:\\Thapar\\Semester 6\\Projects\\Image Processing Project\\DIV2K_train_HR"
VALIDATION_DATASET_PATH = "F:\\Thapar\\Semester 6\\Projects\\Image Processing Project\\DIV2K_valid_HR"

# %%
# Load images
def load_images(path, size=(128, 128)):
    images = []
    for file_name in os.listdir(path):
        img_path = os.path.join(path, file_name)
        if os.path.isfile(img_path):
            img = load_img(img_path, target_size=size)
            img = img_to_array(img) / 255.0
            images.append(img)
    return np.array(images)
# Load datasets
train_lr = load_images(TRAINING_DATASET_PATH, size=(64, 64))  # Low resolution
train_hr = load_images(TRAINING_DATASET_PATH, size=(128, 128))  # High resolution

# %%
# Define the generator
def build_generator():
    def residual_block(inputs):
        x = Conv2D(64, kernel_size=3, strides=1, padding='same')(inputs)
        x = BatchNormalization(momentum=0.8)(x)
        x = LeakyReLU(negative_slope=0.2)(x)
        x = Conv2D(64, kernel_size=3, strides=1, padding='same')(x)
        x = BatchNormalization(momentum=0.8)(x)
        return Add()([inputs, x])

    inputs = Input(shape=(64, 64, 3))
    x = Conv2D(64, kernel_size=9, strides=1, padding='same')(inputs)
    x = LeakyReLU(negative_slope=0.2)(x)

    # Residual blocks
    for _ in range(16):
        x = residual_block(x)

    # Upsampling layer (for 128x128 output)
    x = UpSampling2D(size=2)(x)  # From 64x64 to 128x128
    x = Conv2D(256, kernel_size=3, strides=1, padding='same')(x)
    x = LeakyReLU(negative_slope=0.2)(x)

    # Final layer to produce 128x128x3 output
    outputs = Conv2D(3, kernel_size=9, strides=1, padding='same', activation='tanh')(x)
    return Model(inputs, outputs, name="Generator")

# %%
# Define the discriminator
def build_discriminator(input_shape=(128, 128, 3)):
    inputs = Input(shape=input_shape)
    x = Conv2D(64, kernel_size=3, strides=2, padding='same')(inputs)
    x = LeakyReLU(negative_slope=0.2)(x)

    x = Conv2D(128, kernel_size=3, strides=2, padding='same')(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = LeakyReLU(negative_slope=0.2)(x)

    x = Conv2D(256, kernel_size=3, strides=2, padding='same')(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = LeakyReLU(negative_slope=0.2)(x)

    x = Conv2D(512, kernel_size=3, strides=2, padding='same')(x)
    x = BatchNormalization(momentum=0.8)(x)
    x = LeakyReLU(negative_slope=0.2)(x)

    x = Flatten()(x)
    outputs = Dense(1, activation='sigmoid')(x)
    return Model(inputs, outputs, name="Discriminator")

# %%
# Build and compile the models
generator = build_generator()
discriminator = build_discriminator()

discriminator.compile(optimizer=Adam(learning_rate=0.0002, beta_1=0.5), loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Define the updated generator using the new build_generator function
generator = build_generator()

# Freeze the discriminator while training the generator
discriminator.trainable = False

# Input low-resolution images
lr_inputs = Input(shape=(64, 64, 3))

# Generator outputs high-resolution images (128x128x3)
generated_hr = generator(lr_inputs)

# Discriminator evaluates the generated high-resolution images
validity = discriminator(generated_hr)

# Combine the generator and discriminator into the adversarial model
adversarial_model = Model(lr_inputs, [validity, generated_hr])

# Compile the adversarial model
adversarial_model.compile(
    optimizer=Adam(learning_rate=0.0002, beta_1=0.5),
    loss=['binary_crossentropy', 'mse'],
    loss_weights=[1e-3, 1]
)

# %%
# Compile the discriminator
discriminator.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
print(discriminator.summary())  # This should print model architecture
# Out:
# Model: "Discriminator"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_35 (Conv2D)              │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_18 (LeakyReLU)      │ (None, 64, 64, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_36 (Conv2D)              │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_32          │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_19 (LeakyReLU)      │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_37 (Conv2D)              │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_33          │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_20 (LeakyReLU)      │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_38 (Conv2D)              │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_34          │ (None, 8, 8, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ leaky_re_lu_21 (LeakyReLU)      │ (None, 8, 8, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │        32,769 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,587,329 (6.06 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 1,587,329 (6.06 MB)
# None

# %%
print(imgs_hr.shape)  # Shape of real images
print(fake_hr.shape)  # Shape of fake images
# Out:
# (32, 128, 128, 3)
# (32, 128, 128, 3)

# %%
# Normalize images to range [-1, 1] if using tanh activation
train_lr = (train_lr.astype(np.float32) - 127.5) / 127.5
train_hr = (train_hr.astype(np.float32) - 127.5) / 127.5

# %%
import tensorflow.keras.backend as K

K.clear_session()  # Clears any previous model state
# Out:
# WARNING:tensorflow:From c:\Users\sarda\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
import tensorflow.keras.backend as K

K.clear_session()  # Correct way in TensorFlow 2.x

# %%
# Training parameters
batch_size = 32
epochs = 400

# Training loop
for epoch in range(epochs):
    # Sample random batch of images
    idx = np.random.randint(0, train_lr.shape[0], batch_size)
    imgs_lr, imgs_hr = train_lr[idx], train_hr[idx]

    # Generate high-resolution images
    fake_hr = generator.predict(imgs_lr)

    # Train the discriminator
    real_labels = np.ones((batch_size, 1))
    fake_labels = np.zeros((batch_size, 1))
    d_loss_real = discriminator.train_on_batch(imgs_hr, real_labels)
    d_loss_fake = discriminator.train_on_batch(fake_hr, fake_labels)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train the generator
    g_loss = adversarial_model.train_on_batch(imgs_lr, [real_labels, imgs_hr])

    # Print progress
    print(f"Epoch {epoch + 1}/{epochs}")
    print(f"D Loss: {d_loss[0]:.4f}, D Accuracy: {100 * d_loss[1]:.2f}%, G Loss: {g_loss[0]:.4f}")

# Save the models
generator.save("generator_model.h5")
discriminator.save("discriminator_model.h5")
adversarial_model.save("adversarial_model.h5")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 1/1000
# D Loss: 0.6911, D Accuracy: 59.34%, G Loss: 0.3370
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 2/1000
# D Loss: 0.6914, D Accuracy: 58.13%, G Loss: 0.2949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 3/1000
# D Loss: 0.6917, D Accuracy: 57.19%, G Loss: 0.2622
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 4/1000
# D Loss: 0.6919, D Accuracy: 56.45%, G Loss: 0.2361
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 5/1000
# D Loss: 0.6921, D Accuracy: 55.84%, G Loss: 0.2147
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 6/1000
# D Loss: 0.6922, D Accuracy: 55.34%, G Loss: 0.1969
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 7/1000
# D Loss: 0.6923, D Accuracy: 54.92%, G Loss: 0.1818
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 8/1000
# D Loss: 0.6924, D Accuracy: 54.56%, G Loss: 0.1688
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 9/1000
# D Loss: 0.6924, D Accuracy: 54.25%, G Loss: 0.1576
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 10/1000
# D Loss: 0.6925, D Accuracy: 53.98%, G Loss: 0.1478
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 11/1000
# D Loss: 0.6925, D Accuracy: 53.74%, G Loss: 0.1392
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 12/1000
# D Loss: 0.6926, D Accuracy: 53.53%, G Loss: 0.1315
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 13/1000
# D Loss: 0.6926, D Accuracy: 53.34%, G Loss: 0.1246
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 14/1000
# D Loss: 0.6927, D Accuracy: 53.17%, G Loss: 0.1184
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 15/1000
# D Loss: 0.6927, D Accuracy: 53.02%, G Loss: 0.1128
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 16/1000
# D Loss: 0.6927, D Accuracy: 52.88%, G Loss: 0.1077
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 17/1000
# D Loss: 0.6927, D Accuracy: 52.75%, G Loss: 0.1030
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 18/1000
# D Loss: 0.6928, D Accuracy: 52.64%, G Loss: 0.0988
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 19/1000
# D Loss: 0.6928, D Accuracy: 52.53%, G Loss: 0.0949
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 20/1000
# D Loss: 0.6928, D Accuracy: 52.43%, G Loss: 0.0912
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 21/1000
# D Loss: 0.6928, D Accuracy: 52.34%, G Loss: 0.0879
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 22/1000
# D Loss: 0.6929, D Accuracy: 52.26%, G Loss: 0.0848
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 23/1000
# D Loss: 0.6929, D Accuracy: 52.18%, G Loss: 0.0819
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 24/1000
# D Loss: 0.6929, D Accuracy: 52.10%, G Loss: 0.0792
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 25/1000
# D Loss: 0.6929, D Accuracy: 52.04%, G Loss: 0.0766
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 26/1000
# D Loss: 0.6929, D Accuracy: 51.97%, G Loss: 0.0743
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 27/1000
# D Loss: 0.6929, D Accuracy: 51.91%, G Loss: 0.0720
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 28/1000
# D Loss: 0.6929, D Accuracy: 51.85%, G Loss: 0.0699
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 29/1000
# D Loss: 0.6929, D Accuracy: 51.80%, G Loss: 0.0680
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 30/1000
# D Loss: 0.6929, D Accuracy: 51.75%, G Loss: 0.0661
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 31/1000
# D Loss: 0.6930, D Accuracy: 51.70%, G Loss: 0.0643
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 32/1000
# D Loss: 0.6930, D Accuracy: 51.66%, G Loss: 0.0626
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 33/1000
# D Loss: 0.6930, D Accuracy: 51.62%, G Loss: 0.0611
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 34/1000
# D Loss: 0.6930, D Accuracy: 51.57%, G Loss: 0.0596
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 35/1000
# D Loss: 0.6930, D Accuracy: 51.54%, G Loss: 0.0581
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 36/1000
# D Loss: 0.6930, D Accuracy: 51.50%, G Loss: 0.0567
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 37/1000
# D Loss: 0.6930, D Accuracy: 51.46%, G Loss: 0.0554
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 38/1000
# D Loss: 0.6930, D Accuracy: 51.43%, G Loss: 0.0542
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 39/1000
# D Loss: 0.6930, D Accuracy: 51.40%, G Loss: 0.0530
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 40/1000
# D Loss: 0.6930, D Accuracy: 51.37%, G Loss: 0.0519
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 41/1000
# D Loss: 0.6930, D Accuracy: 51.34%, G Loss: 0.0508
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 42/1000
# D Loss: 0.6930, D Accuracy: 51.31%, G Loss: 0.0497
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 43/1000
# D Loss: 0.6930, D Accuracy: 51.28%, G Loss: 0.0487
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 44/1000
# D Loss: 0.6930, D Accuracy: 51.26%, G Loss: 0.0478
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 45/1000
# D Loss: 0.6930, D Accuracy: 51.23%, G Loss: 0.0469
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 46/1000
# D Loss: 0.6930, D Accuracy: 51.21%, G Loss: 0.0460
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 47/1000
# D Loss: 0.6930, D Accuracy: 51.19%, G Loss: 0.0451
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 48/1000
# D Loss: 0.6930, D Accuracy: 51.16%, G Loss: 0.0443
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 49/1000
# D Loss: 0.6931, D Accuracy: 51.14%, G Loss: 0.0435
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 50/1000
# D Loss: 0.6931, D Accuracy: 51.12%, G Loss: 0.0427
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 51/1000
# D Loss: 0.6931, D Accuracy: 51.10%, G Loss: 0.0420
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 52/1000
# D Loss: 0.6931, D Accuracy: 51.08%, G Loss: 0.0413
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 53/1000
# D Loss: 0.6931, D Accuracy: 51.06%, G Loss: 0.0406
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 54/1000
# D Loss: 0.6931, D Accuracy: 51.05%, G Loss: 0.0399
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 55/1000
# D Loss: 0.6931, D Accuracy: 51.03%, G Loss: 0.0393
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 56/1000
# D Loss: 0.6931, D Accuracy: 51.01%, G Loss: 0.0387
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 57/1000
# D Loss: 0.6931, D Accuracy: 51.00%, G Loss: 0.0381
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 58/1000
# D Loss: 0.6931, D Accuracy: 50.98%, G Loss: 0.0375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 59/1000
# D Loss: 0.6931, D Accuracy: 50.97%, G Loss: 0.0369
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 60/1000
# D Loss: 0.6931, D Accuracy: 50.95%, G Loss: 0.0364
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 61/1000
# D Loss: 0.6931, D Accuracy: 50.94%, G Loss: 0.0358
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 62/1000
# D Loss: 0.6931, D Accuracy: 50.92%, G Loss: 0.0353
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 63/1000
# D Loss: 0.6931, D Accuracy: 50.91%, G Loss: 0.0348
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 64/1000
# D Loss: 0.6931, D Accuracy: 50.90%, G Loss: 0.0343
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 65/1000
# D Loss: 0.6931, D Accuracy: 50.88%, G Loss: 0.0339
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 66/1000
# D Loss: 0.6931, D Accuracy: 50.87%, G Loss: 0.0334
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 67/1000
# D Loss: 0.6931, D Accuracy: 50.86%, G Loss: 0.0329
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 68/1000
# D Loss: 0.6931, D Accuracy: 50.85%, G Loss: 0.0325
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 69/1000
# D Loss: 0.6931, D Accuracy: 50.84%, G Loss: 0.0321
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 70/1000
# D Loss: 0.6931, D Accuracy: 50.83%, G Loss: 0.0317
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 71/1000
# D Loss: 0.6931, D Accuracy: 50.81%, G Loss: 0.0313
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 72/1000
# D Loss: 0.6931, D Accuracy: 50.80%, G Loss: 0.0309
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 73/1000
# D Loss: 0.6931, D Accuracy: 50.79%, G Loss: 0.0305
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 74/1000
# D Loss: 0.6931, D Accuracy: 50.78%, G Loss: 0.0301
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 75/1000
# D Loss: 0.6931, D Accuracy: 50.77%, G Loss: 0.0298
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 76/1000
# D Loss: 0.6931, D Accuracy: 50.77%, G Loss: 0.0294
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 77/1000
# D Loss: 0.6931, D Accuracy: 50.76%, G Loss: 0.0291
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 78/1000
# D Loss: 0.6931, D Accuracy: 50.75%, G Loss: 0.0287
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 79/1000
# D Loss: 0.6931, D Accuracy: 50.74%, G Loss: 0.0284
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 80/1000
# D Loss: 0.6931, D Accuracy: 50.73%, G Loss: 0.0281
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 81/1000
# D Loss: 0.6931, D Accuracy: 50.72%, G Loss: 0.0278
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 82/1000
# D Loss: 0.6931, D Accuracy: 50.71%, G Loss: 0.0274
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 83/1000
# D Loss: 0.6931, D Accuracy: 50.70%, G Loss: 0.0271
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 84/1000
# D Loss: 0.6931, D Accuracy: 50.70%, G Loss: 0.0269
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 85/1000
# D Loss: 0.6931, D Accuracy: 50.69%, G Loss: 0.0266
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 86/1000
# D Loss: 0.6931, D Accuracy: 50.68%, G Loss: 0.0263
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 87/1000
# D Loss: 0.6931, D Accuracy: 50.67%, G Loss: 0.0260
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 88/1000
# D Loss: 0.6931, D Accuracy: 50.67%, G Loss: 0.0257
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 89/1000
# D Loss: 0.6931, D Accuracy: 50.66%, G Loss: 0.0255
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Epoch 90/1000
# D Loss: 0.6931, D Accuracy: 50.65%, G Loss: 0.0252
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 91/1000
# D Loss: 0.6931, D Accuracy: 50.65%, G Loss: 0.0250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 92/1000
# D Loss: 0.6931, D Accuracy: 50.64%, G Loss: 0.0247
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 93/1000
# D Loss: 0.6931, D Accuracy: 50.63%, G Loss: 0.0245
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 94/1000
# D Loss: 0.6931, D Accuracy: 50.63%, G Loss: 0.0242
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 95/1000
# D Loss: 0.6931, D Accuracy: 50.62%, G Loss: 0.0240
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 96/1000
# D Loss: 0.6931, D Accuracy: 50.61%, G Loss: 0.0238
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Epoch 97/1000
# D Loss: 0.6931, D Accuracy: 50.61%, G Loss: 0.0236
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 98/1000
# D Loss: 0.6931, D Accuracy: 50.60%, G Loss: 0.0233
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 99/1000
# D Loss: 0.6931, D Accuracy: 50.60%, G Loss: 0.0231
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 100/1000
# D Loss: 0.6931, D Accuracy: 50.59%, G Loss: 0.0229
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 101/1000
# D Loss: 0.6931, D Accuracy: 50.59%, G Loss: 0.0227
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 102/1000
# D Loss: 0.6931, D Accuracy: 50.58%, G Loss: 0.0225
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 103/1000
# D Loss: 0.6931, D Accuracy: 50.57%, G Loss: 0.0223
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 104/1000
# D Loss: 0.6931, D Accuracy: 50.57%, G Loss: 0.0221
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 105/1000
# D Loss: 0.6931, D Accuracy: 50.56%, G Loss: 0.0219
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 106/1000
# D Loss: 0.6931, D Accuracy: 50.56%, G Loss: 0.0217
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 107/1000
# D Loss: 0.6931, D Accuracy: 50.55%, G Loss: 0.0215
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 108/1000
# D Loss: 0.6931, D Accuracy: 50.55%, G Loss: 0.0213
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 109/1000
# D Loss: 0.6931, D Accuracy: 50.54%, G Loss: 0.0212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 110/1000
# D Loss: 0.6932, D Accuracy: 50.54%, G Loss: 0.0210
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 111/1000
# D Loss: 0.6932, D Accuracy: 50.54%, G Loss: 0.0208
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 112/1000
# D Loss: 0.6932, D Accuracy: 50.53%, G Loss: 0.0206
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Epoch 113/1000
# D Loss: 0.6932, D Accuracy: 50.53%, G Loss: 0.0205
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 114/1000
# D Loss: 0.6932, D Accuracy: 50.52%, G Loss: 0.0203
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 115/1000
# D Loss: 0.6932, D Accuracy: 50.52%, G Loss: 0.0202
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 116/1000
# D Loss: 0.6932, D Accuracy: 50.51%, G Loss: 0.0200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 117/1000
# D Loss: 0.6932, D Accuracy: 50.51%, G Loss: 0.0198
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 118/1000
# D Loss: 0.6932, D Accuracy: 50.51%, G Loss: 0.0197
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 119/1000
# D Loss: 0.6932, D Accuracy: 50.50%, G Loss: 0.0195
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 120/1000
# D Loss: 0.6932, D Accuracy: 50.50%, G Loss: 0.0194
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 121/1000
# D Loss: 0.6932, D Accuracy: 50.49%, G Loss: 0.0192
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 122/1000
# D Loss: 0.6932, D Accuracy: 50.49%, G Loss: 0.0191
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 123/1000
# D Loss: 0.6932, D Accuracy: 50.49%, G Loss: 0.0189
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 124/1000
# D Loss: 0.6932, D Accuracy: 50.48%, G Loss: 0.0188
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 125/1000
# D Loss: 0.6932, D Accuracy: 50.48%, G Loss: 0.0187
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 126/1000
# D Loss: 0.6932, D Accuracy: 50.47%, G Loss: 0.0185
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 127/1000
# D Loss: 0.6932, D Accuracy: 50.47%, G Loss: 0.0184
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 128/1000
# D Loss: 0.6932, D Accuracy: 50.47%, G Loss: 0.0183
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 129/1000
# D Loss: 0.6932, D Accuracy: 50.46%, G Loss: 0.0181
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 130/1000
# D Loss: 0.6932, D Accuracy: 50.46%, G Loss: 0.0180
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 131/1000
# D Loss: 0.6932, D Accuracy: 50.46%, G Loss: 0.0179
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 132/1000
# D Loss: 0.6932, D Accuracy: 50.45%, G Loss: 0.0178
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Epoch 133/1000
# D Loss: 0.6932, D Accuracy: 50.45%, G Loss: 0.0176
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 134/1000
# D Loss: 0.6932, D Accuracy: 50.45%, G Loss: 0.0175
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 135/1000
# D Loss: 0.6932, D Accuracy: 50.44%, G Loss: 0.0174
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 136/1000
# D Loss: 0.6932, D Accuracy: 50.44%, G Loss: 0.0173
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Epoch 137/1000
# D Loss: 0.6932, D Accuracy: 50.44%, G Loss: 0.0172
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 138/1000
# D Loss: 0.6932, D Accuracy: 50.43%, G Loss: 0.0170
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 139/1000
# D Loss: 0.6932, D Accuracy: 50.43%, G Loss: 0.0169
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 140/1000
# D Loss: 0.6932, D Accuracy: 50.43%, G Loss: 0.0168
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 141/1000
# D Loss: 0.6932, D Accuracy: 50.43%, G Loss: 0.0167
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# Epoch 142/1000
# D Loss: 0.6932, D Accuracy: 50.42%, G Loss: 0.0166
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Epoch 143/1000
# D Loss: 0.6932, D Accuracy: 50.42%, G Loss: 0.0165
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Epoch 144/1000
# D Loss: 0.6932, D Accuracy: 50.42%, G Loss: 0.0164
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
